# %% [markdown]
# <a href="https://colab.research.google.com/github/luciaetchecopar/Python-for-data-analysis-/blob/master/preliminary_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages('psych')
library(psych)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘mnormt’

# %%
install.packages("Hmisc")
library("Hmisc")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘deldir’, ‘RcppEigen’, ‘png’, ‘jpeg’, ‘interp’, ‘checkmate’, ‘htmlwidgets’, ‘Formula’, ‘latticeExtra’, ‘gridExtra’, ‘htmlTable’, ‘viridis’
#
#
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggplot2’
#
#
# The following objects are masked from ‘package:psych’:
#
#     %+%, alpha
#
#
#
# Attaching package: ‘Hmisc’
#
#
# The following object is masked from ‘package:psych’:
#
#     describe
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
churn_bank = read.csv('/content/Bank Customer Churn Prediction.csv')

# %%
dim(churn_bank)
# Out:
# [1] 10000    12

# %%
head(churn_bank)
# Out:
#   customer_id credit_score country gender age tenure balance   products_number
# 1 15634602    619          France  Female 42  2           0.00 1
# 2 15647311    608          Spain   Female 41  1       83807.86 1
# 3 15619304    502          France  Female 42  8      159660.80 3
# 4 15701354    699          France  Female 39  1           0.00 2
# 5 15737888    850          Spain   Female 43  2      125510.82 1
# 6 15574012    645          Spain   Male   44  8      113755.78 2
#   credit_card active_member estimated_salary churn
# 1 1           1             101348.88        1
# 2 0           1             112542.58        0
# 3 1           0             113931.57        1
# 4 0           0              93826.63        0
# 5 1           1              79084.10        0
# 6 1           0             149756.71        1

# %%
describe(churn_bank)
# Out:
# churn_bank
#
#  12  Variables      10000  Observations
# --------------------------------------------------------------------------------
# customer_id
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#    10000        0    10000        1 15690941    83068 15578824 15591167
#      .25      .50      .75      .90      .95
# 15628528 15690738 15753234 15790831 15803034
#
# lowest : 15565701 15565706 15565714 15565779 15565796
# highest: 15815628 15815645 15815656 15815660 15815690
# --------------------------------------------------------------------------------
# credit_score
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#    10000        0      460        1    650.5      110      489      521
#      .25      .50      .75      .90      .95
#      584      652      718      778      812
#
# lowest : 350 351 358 359 363, highest: 846 847 848 849 850
# --------------------------------------------------------------------------------
# ...

# %%
churn_bank$gender <- unclass(factor(churn_bank$gender))
churn_bank$country <- unclass(factor(churn_bank$country))

# %%
churn_bank <- sapply(churn_bank, as.numeric )

# %%
install.packages("corrplot")
library(corrplot)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# corrplot 0.92 loaded

# %%
corrplot(cor(churn_bank))
# Out:
# Plot with title “”

# %%
digital_mktg = read.csv('/content/data1.csv', sep = ';')

# %%
head(digital_mktg)
# Out:
#   account.length location.code user.id credit.card.info.save push.status
# 1 128            415           3824657 no                    yes
# 2 107            415           3717191 no                    yes
# 3 137            415           3581921 no                    no
# 4  84            408           3759999 yes                   no
# 5  75            415           3306626 yes                   no
# 6 118            510           3918027 yes                   no
#   add.to.wishlist desktop.sessions app.sessions desktop.transactions
# 1 25              265              45           17
# 2 26              162              27           17
# 3  0              243              41           10
# 4  0              299              51            5
# 5  0              167              28           13
# 6  0              223              38           19
#   total.product.detail.views session.duration promotion.clicks avg.order.value
# ...

# %%
describe(digital_mktg)
# Out:
# digital_mktg
#
#  20  Variables      3333  Observations
# --------------------------------------------------------------------------------
# account.length
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#     3333        0      212        1    101.1    45.01       35       50
#      .25      .50      .75      .90      .95
#       74      101      127      152      167
#
# lowest :   1   2   3   4   5, highest: 221 224 225 232 243
# --------------------------------------------------------------------------------
# location.code
#        n  missing distinct     Info     Mean      Gmd
#     3333        0        3    0.846    437.2    38.46
#
# Value        408   415   510
# Frequency    838  1655   840
# Proportion 0.251 0.497 0.252
# --------------------------------------------------------------------------------
# user.id
#        n  missing distinct     Info     Mean      Gmd      .05      .10
# ...

# %%
digital_mktg$credit.card.info.save <- as.numeric(as.character(digital_mktg$credit.card.info.save))
digital_mktg$push.status <- as.numeric(as.character(digital_mktg$push.status))
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
digital_mktg <- sapply( digital_mktg, as.numeric )
# Out:
# Warning message in lapply(X = X, FUN = FUN, ...):
# “NAs introduced by coercion”
# Warning message in lapply(X = X, FUN = FUN, ...):
# “NAs introduced by coercion”
# Warning message in lapply(X = X, FUN = FUN, ...):
# “NAs introduced by coercion”
# Warning message in lapply(X = X, FUN = FUN, ...):
# “NAs introduced by coercion”

# %%
corrplot(cor(digital_mktg))
# Out:
# Plot with title “”

# %%
bank = read.csv('/content/bank-full.csv', sep = ';')

# %%
head(bank)
# Out:
#   age job          marital education default balance housing loan contact day
# 1 58  management   married tertiary  no      2143    yes     no   unknown 5
# 2 44  technician   single  secondary no        29    yes     no   unknown 5
# 3 33  entrepreneur married secondary no         2    yes     yes  unknown 5
# 4 47  blue-collar  married unknown   no      1506    yes     no   unknown 5
# 5 33  unknown      single  unknown   no         1    no      no   unknown 5
# 6 35  management   married tertiary  no       231    yes     no   unknown 5
#   month duration campaign pdays previous poutcome y
# 1 may   261      1        -1    0        unknown  no
# 2 may   151      1        -1    0        unknown  no
# 3 may    76      1        -1    0        unknown  no
# 4 may    92      1        -1    0        unknown  no
# 5 may   198      1        -1    0        unknown  no
# 6 may   139      1        -1    0        unknown  no

# %%
head(churn_bank)
# Out:
#   customer_id credit_score country gender age tenure balance   products_number
# 1 15634602    619          France  Female 42  2           0.00 1
# 2 15647311    608          Spain   Female 41  1       83807.86 1
# 3 15619304    502          France  Female 42  8      159660.80 3
# 4 15701354    699          France  Female 39  1           0.00 2
# 5 15737888    850          Spain   Female 43  2      125510.82 1
# 6 15574012    645          Spain   Male   44  8      113755.78 2
#   credit_card active_member estimated_salary churn
# 1 1           1             101348.88        1
# 2 0           1             112542.58        0
# 3 1           0             113931.57        1
# 4 0           0              93826.63        0
# 5 1           1              79084.10        0
# 6 1           0             149756.71        1

# %%
dim(churn_bank)
# Out:
# [1] 10000    12

# %%
dim(bank)
# Out:
# [1] 45211    17

# %%
#let's see how different variables interact with the result
churn_yes = churn_bank[churn_bank$churn == 1, ]   
churn_no = churn_bank[churn_bank$churn == 0, ]

# %%
hist(churn_yes$age, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_yes$age”

# %%
hist(churn_no$age, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_no$age”

# %%
#we can see that people that churn has a more normal age distribution, and people that 
# don't is more biased to the left

# %%
hist(churn_yes$balance, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_yes$balance”

# %%
hist(churn_no$balance, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_no$balance”

# %%
#balance has lot of missing data - can we estimate it somehow?

# %%
hist(churn_yes$estimated_salary, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_yes$estimated_salary”

# %%
hist(churn_no$estimated_salary, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_no$estimated_salary”

# %%
#salary is uniform - probably it doesn't make a difference

# %%
hist(churn_yes$credit_score, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_yes$credit_score”

# %%
hist(churn_no$credit_score, prob = TRUE)
# Out:
# Plot with title “Histogram of churn_no$credit_score”

# %%
#let's see how different variables interact with the result
bank_yes = bank[bank$y == 'yes', ]   
bank_no = bank[bank$y == 'no', ]

# %%
hist(bank_yes$age, prob = TRUE)
# Out:
# Plot with title “Histogram of bank_yes$age”

# %%
hist(bank_no$age, prob = TRUE)
# Out:
# Plot with title “Histogram of bank_no$age”

# %%
hist(bank_yes$balance, prob = TRUE)
# Out:
# Plot with title “Histogram of bank_yes$balance”

# %%
hist(bank_no$balance, prob = TRUE)
# Out:
# Plot with title “Histogram of bank_no$balance”
